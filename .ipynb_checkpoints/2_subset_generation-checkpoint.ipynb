# %% [markdown]
# # Phase 1 — Stratified Subset Generation
# This notebook creates **3–5 manageable subsets** (~50k–100k docs) by:
# - Clustering queries via MiniLM embeddings + KMeans (proportional sampling)
# - Preserving document-length diversity via binning
#
# > Matches SOP Step 2 (Create Stratified Subsets).

# %%
import sys, subprocess, importlib.util

# 1) Remove the broken installs in THIS kernel
subprocess.run([sys.executable, "-m", "pip", "uninstall", "-y",
                "sentence-transformers", "transformers", "tokenizers", "huggingface-hub"], check=False)

# 2) Reinstall compatible, stable versions (no cache to avoid partial wheels)
env = {"PIP_NO_CACHE_DIR": "1"}
subprocess.run([sys.executable, "-m", "pip", "install",
                "transformers==4.44.2",           # solid 4.x release
                "sentence-transformers==3.0.1",
                "huggingface-hub>=0.24.0",
                "tokenizers>=0.15,<0.23",         # keeps ABI compatible with 4.44.x
                "safetensors>=0.4.3"], env=env, check=True)

# 3) Sanity check the exact symbols that failed before
code = "from transformers import PreTrainedModel, TrainingArguments; print('OK transformers'); " \
       "from sentence_transformers import SentenceTransformer; print('OK sentence-transformers')"
subprocess.run([sys.executable, "-c", code], check=True)

print("Reinstall done.")
# Out:
# Found existing installation: sentence-transformers 3.0.1
# Uninstalling sentence-transformers-3.0.1:
#   Successfully uninstalled sentence-transformers-3.0.1
# Found existing installation: transformers 4.57.1
# Uninstalling transformers-4.57.1:
#   Successfully uninstalled transformers-4.57.1
# Found existing installation: tokenizers 0.22.1
# Uninstalling tokenizers-0.22.1:
#   Successfully uninstalled tokenizers-0.22.1
# Found existing installation: huggingface-hub 0.36.0
# Uninstalling huggingface-hub-0.36.0:
#   Successfully uninstalled huggingface-hub-0.36.0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting transformers==4.44.2
#   Downloading transformers-4.44.2-py3-none-any.whl.metadata (43 kB)
# Collecting sentence-transformers==3.0.1
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Collecting huggingface-hub>=0.24.0
#   Downloading huggingface_hub-1.0.1-py3-none-any.whl.metadata (13 kB)
# Collecting tokenizers<0.23,>=0.15
#   Downloading tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: safetensors>=0.4.3 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (0.6.2)
# Requirement already satisfied: filelock in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from transformers==4.44.2) (3.16.1)
# Collecting huggingface-hub>=0.24.0
#   Downloading huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from transformers==4.44.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from transformers==4.44.2) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers==4.44.2) (5.4.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from transformers==4.44.2) (2025.10.23)
# Requirement already satisfied: requests in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from transformers==4.44.2) (2.32.3)
# Collecting tokenizers<0.23,>=0.15
#   Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from transformers==4.44.2) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from sentence-transformers==3.0.1) (2.4.1+cu121)
# Requirement already satisfied: scikit-learn in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from sentence-transformers==3.0.1) (1.4.2)
# Requirement already satisfied: scipy in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from sentence-transformers==3.0.1) (1.14.1)
# Requirement already satisfied: Pillow in /usr/lib/python3/dist-packages (from sentence-transformers==3.0.1) (9.0.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from huggingface-hub>=0.24.0) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from huggingface-hub>=0.24.0) (4.12.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from huggingface-hub>=0.24.0) (1.2.0)
# Requirement already satisfied: sympy in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (1.14.0)
# Requirement already satisfied: networkx in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (3.4.2)
# Requirement already satisfied: jinja2 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers==3.0.1) (12.9.86)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers==3.0.1) (2.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from requests->transformers==4.44.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->transformers==4.44.2) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->transformers==4.44.2) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->transformers==4.44.2) (2020.6.20)
# Requirement already satisfied: joblib>=1.2.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from scikit-learn->sentence-transformers==3.0.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from scikit-learn->sentence-transformers==3.0.1) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence-transformers==3.0.1) (1.3.0)
# Downloading transformers-4.44.2-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 195.7 kB/s  0:01:12
# Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
# Downloading huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 399.7 kB/s  0:00:01
# Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 328.1 kB/s  0:00:10
# Installing collected packages: huggingface-hub, tokenizers, transformers, sentence-transformers
#   WARNING: The scripts hf, huggingface-cli and tiny-agents are installed in '/home/mallarapuhemavarshini/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script transformers-cli is installed in '/home/mallarapuhemavarshini/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed huggingface-hub-0.36.0 sentence-transformers-3.0.1 tokenizers-0.19.1 transformers-4.44.2
# OK transformers
# OK sentence-transformers
# Reinstall done.

# %%
# Optional: install
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ir_datasets==0.5.6 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (0.5.6)
# Requirement already satisfied: rank_bm25==0.2.2 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: sentence-transformers==3.0.1 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (3.0.1)
# Requirement already satisfied: faiss-cpu==1.8.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: scikit-learn==1.4.2 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied: tqdm==4.66.4 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (4.66.4)
# Requirement already satisfied: numpy==1.26.4 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: matplotlib>=3.8.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (3.9.2)
# Requirement already satisfied: transformers>=4.41.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (4.57.1)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (4.12.3)
# Requirement already satisfied: inscriptis>=2.2.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (2.6.0)
# Requirement already satisfied: lxml>=4.5.2 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/lib/python3/dist-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (5.4.1)
# Requirement already satisfied: requests>=2.22.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (2.6)
# Requirement already satisfied: lz4>=3.1.10 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (4.4.5)
# Requirement already satisfied: warc3-wet>=0.2.3 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (0.1.10)
# Requirement already satisfied: ijson>=3.1.3 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (3.4.0.post0)
# Requirement already satisfied: pyautocorpus>=0.1.1 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (0.1.12)
# Requirement already satisfied: unlzw3>=0.2.1 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: torch>=1.11.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from sentence-transformers==3.0.1->-r requirements.txt (line 3)) (2.4.1+cu121)
# Requirement already satisfied: scipy in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from sentence-transformers==3.0.1->-r requirements.txt (line 3)) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from sentence-transformers==3.0.1->-r requirements.txt (line 3)) (0.36.0)
# Requirement already satisfied: Pillow in /usr/lib/python3/dist-packages (from sentence-transformers==3.0.1->-r requirements.txt (line 3)) (9.0.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from scikit-learn==1.4.2->-r requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from scikit-learn==1.4.2->-r requirements.txt (line 5)) (3.5.0)
# Requirement already satisfied: filelock in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from transformers>=4.41.0->-r requirements.txt (line 9)) (3.16.1)
# Requirement already satisfied: packaging>=20.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from transformers>=4.41.0->-r requirements.txt (line 9)) (24.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from transformers>=4.41.0->-r requirements.txt (line 9)) (2025.10.23)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from transformers>=4.41.0->-r requirements.txt (line 9)) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from transformers>=4.41.0->-r requirements.txt (line 9)) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from matplotlib>=3.8.0->-r requirements.txt (line 8)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from matplotlib>=3.8.0->-r requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from matplotlib>=3.8.0->-r requirements.txt (line 8)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from matplotlib>=3.8.0->-r requirements.txt (line 8)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.8.0->-r requirements.txt (line 8)) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from matplotlib>=3.8.0->-r requirements.txt (line 8)) (2.9.0.post0)
# Requirement already satisfied: soupsieve>1.2 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from beautifulsoup4>=4.4.1->ir_datasets==0.5.6->-r requirements.txt (line 1)) (2.6)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.8.0->-r requirements.txt (line 8)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from requests>=2.22.0->ir_datasets==0.5.6->-r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.22.0->ir_datasets==0.5.6->-r requirements.txt (line 1)) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.22.0->ir_datasets==0.5.6->-r requirements.txt (line 1)) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.22.0->ir_datasets==0.5.6->-r requirements.txt (line 1)) (2020.6.20)
# Requirement already satisfied: sympy in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (1.14.0)
# Requirement already satisfied: networkx in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (3.4.2)
# Requirement already satisfied: jinja2 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (12.9.86)
# Requirement already satisfied: cbor>=1.0.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from trec-car-tools>=2.5.4->ir_datasets==0.5.6->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (1.3.0)

# %%
from __future__ import annotations
import json, random
from pathlib import Path
from typing import Dict, List, Set
import numpy as np
from tqdm import tqdm
from sklearn.cluster import KMeans
from sentence_transformers import SentenceTransformer

RANDOM_SEED = 13
random.seed(RANDOM_SEED); np.random.seed(RANDOM_SEED)

WORK_DIR = Path("./work")
DATASET = "beir/trec-covid"
#NUM_SUBSETS = 3
#TARGET_DOCS_PER_SUBSET = 80000
QUERY_CLUSTERS = 12
NUM_SUBSETS = 2
TARGET_DOCS_PER_SUBSET = 5000
TARGET_QUERIES_PER_SUBSET = 100
RANDOM_SEED = 42


ds_dir = WORK_DIR / "datasets" / DATASET.replace("/", "_")
subs_root = WORK_DIR / "subsets" / DATASET.replace("/", "_")
subs_root.mkdir(parents=True, exist_ok=True)

def read_jsonl(path: Path):
    with path.open("r", encoding="utf-8") as f:
        for line in f:
            yield json.loads(line)

corpus_path = ds_dir / "corpus.jsonl"
queries_path = ds_dir / "queries.jsonl"
qrels_path = ds_dir / "qrels.jsonl"

# Load into memory structures
corpus_map = {r["doc_id"]: r for r in read_jsonl(corpus_path)}
qmap = {r["qid"]: r["text"] for r in read_jsonl(queries_path)}
qrels = {}
for r in read_jsonl(qrels_path):
    qrels.setdefault(r["qid"], {})[r["doc_id"]] = int(r["rel"])

# %%
print("Dataset directory:", ds_dir)
print("Queries file exists:", (ds_dir / 'queries.jsonl').exists())
# Out:
# Dataset directory: work/datasets/beir_trec-covid
# Queries file exists: True

# %%
qmap = {r["qid"]: r["text"] for r in read_jsonl(queries_path)}
print("Total queries loaded:", len(qmap))
print("Sample:", list(qmap.items())[:3])
# Out:
# Total queries loaded: 50
# Sample: [('1', 'what is the origin of covid-19'), ('2', 'how does the coronavirus respond to changes in the weather'), ('3', 'will sars-cov2 infected people develop immunity? is cross protection possible?')]

# %%
import torch, os, subprocess, sys
print("torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    # optional: basic memory info
    try:
        print(subprocess.check_output(["nvidia-smi", "--query-gpu=memory.total,memory.used", "--format=csv,noheader"]).decode())
    except Exception as e:
        print("nvidia-smi not available:", e)
else:
    print("No CUDA visible to PyTorch.")
# Out:
# torch: 2.4.1+cu121
# CUDA available: True
# GPU: NVIDIA GeForce RTX 3050 Laptop GPU
# 4096 MiB, 2667 MiB

# %%
# Build query embeddings + KMeans clusters
model_name = "sentence-transformers/all-MiniLM-L6-v2"
model = SentenceTransformer(model_name)
qids = list(qmap.keys())
qtexts = [qmap[qid] for qid in qids]
#qemb = model.encode(qtexts, batch_size=256, show_progress_bar=True, convert_to_numpy=True, normalize_embeddings=True)
qemb = model.encode(qtexts, batch_size=256, show_progress_bar=False, convert_to_numpy=True, normalize_embeddings=True)

kmeans = KMeans(n_clusters=QUERY_CLUSTERS, random_state=RANDOM_SEED, n_init=10)
labels = kmeans.fit_predict(qemb)

buckets = {}
for qid, lab in zip(qids, labels):
    buckets.setdefault(int(lab), []).append(qid)
# Out:
# /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
# Doc-length bins for diversity
import numpy as np
lengths, docids = [], []
for d in corpus_map.values():
    lengths.append(int(d["len"])); docids.append(d["doc_id"])
lengths = np.array(lengths)
edges = np.quantile(lengths, q=np.linspace(0, 1, 6))
bins = {i: [] for i in range(5)}
for did, L in zip(docids, lengths):
    idx = int(np.searchsorted(edges, L, side="right") - 1)
    idx = min(max(idx, 0), 4)
    bins[idx].append(did)

# %%
import numpy as np, random, json
from pathlib import Path

random.seed(RANDOM_SEED); np.random.seed(RANDOM_SEED)

# --- load maps (keep your existing read_jsonl) ---
# corpus_map: {doc_id: {...}}
# qmap: {qid: text}
# qrels: {qid: {doc_id: rel, ...}}

all_qids = list(qmap.keys())
random.shuffle(all_qids)

# Split queries into disjoint chunks (balanced)
q_chunks = np.array_split(all_qids, NUM_SUBSETS)

used_docs = set()
subs_root = Path("./work/subsets/beir_trec-covid")
subs_root.mkdir(parents=True, exist_ok=True)

for si in range(NUM_SUBSETS):
    sub_dir = subs_root / f"subset_{si+1}"
    sub_dir.mkdir(parents=True, exist_ok=True)

    # Pick queries for this subset (cap per target)
    qids_chunk = list(q_chunks[si])
    sampled_qids = qids_chunk[:min(TARGET_QUERIES_PER_SUBSET, len(qids_chunk))]

    # Build doc pool: positives from qrels for these queries
    doc_pool = set()
    for qid in sampled_qids:
        for did, rel in qrels.get(qid, {}).items():
            if rel > 0:
                doc_pool.add(did)

    # Top up with unused docs to reach TARGET_DOCS_PER_SUBSET
    if len(doc_pool) < TARGET_DOCS_PER_SUBSET:
        need = TARGET_DOCS_PER_SUBSET - len(doc_pool)
        candidates = [d for d in corpus_map.keys() if d not in used_docs and d not in doc_pool]
        random.shuffle(candidates)
        doc_pool.update(candidates[:max(0, need)])

    # Update global used set to reduce overlap across subsets
    used_docs.update(doc_pool)

    # Write files
    with (sub_dir / "queries.jsonl").open("w", encoding="utf-8") as f:
        for qid in sampled_qids:
            f.write(json.dumps({"qid": qid, "text": qmap[qid]}, ensure_ascii=False) + "\n")

    with (sub_dir / "corpus.jsonl").open("w", encoding="utf-8") as f:
        for did in doc_pool:
            if did in corpus_map:
                f.write(json.dumps(corpus_map[did], ensure_ascii=False) + "\n")

    doc_pool_set = set(doc_pool)
    with (sub_dir / "qrels.jsonl").open("w", encoding="utf-8") as f:
        for qid in sampled_qids:
            for did, rel in qrels.get(qid, {}).items():
                if did in doc_pool_set and rel > 0:
                    f.write(json.dumps({"qid": qid, "doc_id": did, "rel": int(rel)}, ensure_ascii=False) + "\n")

    print(f"[subset {si+1}] queries={len(sampled_qids)} docs={len(doc_pool)} -> {sub_dir}")
# Out:
# [subset 1] queries=25 docs=10283 -> work/subsets/beir_trec-covid/subset_1
# [subset 2] queries=25 docs=10420 -> work/subsets/beir_trec-covid/subset_2

# %%
print("Loading from:", corpus_path.resolve())
num_lines = sum(1 for _ in open(corpus_path, "rb"))
print("Actual lines in corpus.jsonl:", num_lines)
print("len(corpus_map):", len(corpus_map))
# Out:
# Loading from: /home/mallarapuhemavarshini/Desktop/Mystudies/ir/rough/hybrid_retrieval_phase1_notebooks/work/datasets/beir_trec-covid/corpus.jsonl
# Actual lines in corpus.jsonl: 10000
# len(corpus_map): 10000

# %%
ALLOWED_DOCS = set(corpus_map.keys())  # == your 1k docs

for si in range(NUM_SUBSETS):
    sub_dir = subs_root / f"subset_{si+1}"
    sub_dir.mkdir(parents=True, exist_ok=True)

    # sample queries (your logic is fine; trec-covid ~50 queries -> you get ~50)
    sampled_qids = []
    total_q = sum(len(v) for v in buckets.values())
    target_queries = min(50000, max(1000, total_q // 2))
    for _, qlist in buckets.items():
        k = max(1, int(len(qlist) * target_queries / total_q))
        sampled_qids.extend(random.sample(qlist, k=min(k, len(qlist))))
    sampled_qids = sorted(set(sampled_qids))

    # 1) positives, but only from ALLOWED_DOCS
    doc_pool = set()
    for qid in sampled_qids:
        for did, rel in qrels.get(qid, {}).items():
            if rel > 0 and did in ALLOWED_DOCS:
                doc_pool.add(did)

    # 2) top up from bins, but only with ALLOWED_DOCS
    remaining = max(0, TARGET_DOCS_PER_SUBSET - len(doc_pool))
    if remaining > 0:
        per_bin = max(1, remaining // max(1, len(bins)))
        for _, dids in bins.items():
            candidates = list(set(dids) & ALLOWED_DOCS - doc_pool)
            take = min(per_bin, len(candidates))
            if take > 0:
                doc_pool.update(random.sample(candidates, take))

    # 3) fallback top-up strictly from ALLOWED_DOCS
    if len(doc_pool) < TARGET_DOCS_PER_SUBSET:
        need = TARGET_DOCS_PER_SUBSET - len(doc_pool)
        pool = list(ALLOWED_DOCS - doc_pool)
        if pool:
            doc_pool.update(random.sample(pool, min(need, len(pool))))

    # 4) hard cap to target (in case positives already exceed)
    if len(doc_pool) > TARGET_DOCS_PER_SUBSET:
        doc_pool = set(random.sample(list(doc_pool), TARGET_DOCS_PER_SUBSET))

    # write
    with (sub_dir / "queries.jsonl").open("w", encoding="utf-8") as f:
        for qid in sampled_qids:
            f.write(json.dumps({"qid": qid, "text": qmap[qid]}, ensure_ascii=False) + "\n")

    written_docs = 0
    with (sub_dir / "corpus.jsonl").open("w", encoding="utf-8") as f:
        for did in doc_pool:
            f.write(json.dumps(corpus_map[did], ensure_ascii=False) + "\n")
            written_docs += 1

    # only write qrels that point to actually written docs
    doc_pool_set = set(doc_pool)
    with (sub_dir / "qrels.jsonl").open("w", encoding="utf-8") as f:
        for qid in sampled_qids:
            for did, rel in qrels.get(qid, {}).items():
                if did in doc_pool_set and rel > 0:
                    f.write(json.dumps({"qid": qid, "doc_id": did, "rel": int(rel)}, ensure_ascii=False) + "\n")

    print(f"[subset {si+1}] queries={len(sampled_qids)} docs_written={written_docs} -> {sub_dir}")
# Out:
# [subset 1] queries=50 docs_written=5000 -> work/subsets/beir_trec-covid/subset_1
# [subset 2] queries=50 docs_written=5000 -> work/subsets/beir_trec-covid/subset_2

# %%
ALLOWED_DOCS = set(corpus_map.keys())  # == your 1k docs

for si in range(NUM_SUBSETS):
    sub_dir = subs_root / f"subset_{si+1}"
    sub_dir.mkdir(parents=True, exist_ok=True)

    sampled_qids = []
    total_q = sum(len(v) for v in buckets.values())
    target_queries = min(50000, max(1000, total_q // 2))
    for _, qlist in buckets.items():
        k = max(1, int(len(qlist) * target_queries / total_q))
        take = random.sample(qlist, k=min(k, len(qlist)))
        sampled_qids.extend(take)
    sampled_qids = sorted(set(sampled_qids))

    # collect positives (raw)
    doc_pool_raw = set()
    for qid in sampled_qids:
        for did, rel in qrels.get(qid, {}).items():
            if rel > 0:
                doc_pool_raw.add(did)

    # keep only docs you actually loaded
    doc_pool = doc_pool_raw & ALLOWED_DOCS

    # top up from bins but only with allowed docs
    remaining = max(0, TARGET_DOCS_PER_SUBSET - len(doc_pool))
    if remaining > 0:
        per_bin = max(1, remaining // max(1, len(bins)))
        for _, dids in bins.items():
            candidates = (set(dids) & ALLOWED_DOCS) - doc_pool
            take = min(per_bin, len(candidates))
            if take > 0:
                doc_pool.update(random.sample(list(candidates), take))

    # final fallback strictly from allowed docs
    if len(doc_pool) < TARGET_DOCS_PER_SUBSET:
        need = TARGET_DOCS_PER_SUBSET - len(doc_pool)
        pool = list(ALLOWED_DOCS - doc_pool)
        if pool:
            doc_pool.update(random.sample(pool, min(need, len(pool))))

    # optional: hard cap per subset
    if len(doc_pool) > TARGET_DOCS_PER_SUBSET:
        doc_pool = set(random.sample(list(doc_pool), TARGET_DOCS_PER_SUBSET))

    # write
    with (sub_dir / "queries.jsonl").open("w", encoding="utf-8") as f:
        for qid in sampled_qids:
            f.write(json.dumps({"qid": qid, "text": qmap[qid]}, ensure_ascii=False) + "\n")

    with (sub_dir / "corpus.jsonl").open("w", encoding="utf-8") as f:
        for did in doc_pool:
            f.write(json.dumps(corpus_map[did], ensure_ascii=False) + "\n")

    # qrels only for actually written docs
    with (sub_dir / "qrels.jsonl").open("w", encoding="utf-8") as f:
        for qid in sampled_qids:
            for did, rel in qrels.get(qid, {}).items():
                if did in doc_pool and rel > 0:
                    f.write(json.dumps({"qid": qid, "doc_id": did, "rel": int(rel)}, ensure_ascii=False) + "\n")

    print(f"[subset {si+1}] queries={len(sampled_qids)} "
          f"doc_pool_raw={len(doc_pool_raw)} docs_written={len(doc_pool)} -> {sub_dir}")
# Out:
# [subset 1] queries=50 doc_pool_raw=17537 docs_written=5000 -> work/subsets/beir_trec-covid/subset_1
# [subset 2] queries=50 doc_pool_raw=17537 docs_written=5000 -> work/subsets/beir_trec-covid/subset_2
