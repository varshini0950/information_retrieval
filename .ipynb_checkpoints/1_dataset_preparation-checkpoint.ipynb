# %% [markdown]
# # Phase 1 — Dataset Preparation
# This notebook loads datasets via **ir_datasets**, performs lightweight cleaning and truncation, and exports:
# - `corpus.jsonl` — document id, cleaned text, length (tokens)
# - `queries.jsonl` — query id, cleaned text
# - `qrels.jsonl` — qrels triples
#
# > Matches SOP Step 1 (Dataset Setup & Preprocessing).

# %%
import sys, os, subprocess
os.environ["PIP_NO_CACHE_DIR"]="1"
subprocess.run([sys.executable, "-m", "pip", "install", "-U", "pip"], check=True)
subprocess.run([sys.executable, "-m", "pip", "install",
                "--index-url","https://download.pytorch.org/whl/cu121",
                "torch==2.4.1"], check=True)

# verify cuDNN wheel is present
import pathlib, importlib
import nvidia.cudnn as nc
libdir = pathlib.Path(nc.__file__).parent / "lib"
print("cuDNN libs:", [p.name for p in libdir.glob("libcudnn*.so*")])
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (25.3)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Collecting torch==2.4.1
#   Downloading https://download.pytorch.org/whl/cu121/torch-2.4.1%2Bcu121-cp310-cp310-linux_x86_64.whl (798.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.9/798.9 MB 6.6 MB/s  0:01:46 eta 0:00:010:00:03
# Requirement already satisfied: filelock in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (4.12.2)
# Requirement already satisfied: sympy in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (1.14.0)
# Requirement already satisfied: networkx in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (3.4.2)
# Requirement already satisfied: jinja2 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (3.1.4)
# Requirement already satisfied: fsspec in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.4.1) (12.9.86)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->torch==2.4.1) (2.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from sympy->torch==2.4.1) (1.3.0)
# Installing collected packages: torch
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.11 requires torchvision>=0.8.2, which is not installed.
# fastai 2.7.11 requires torch<1.14,>=1.7, but you have torch 2.4.1+cu121 which is incompatible.
# Successfully installed torch-2.4.1+cu121
# cuDNN libs: ['libcudnn_engines_runtime_compiled.so.9', 'libcudnn_cnn.so.9', 'libcudnn_heuristic.so.9', 'libcudnn_adv.so.9', 'libcudnn_graph.so.9', 'libcudnn_ops.so.9', 'libcudnn.so.9', 'libcudnn_engines_precompiled.so.9']

# %%
import sys, subprocess
subprocess.run([sys.executable, "-m", "pip", "uninstall", "-y", "fastai"], check=False)
# (optional) also remove fastai extras you don't need:
subprocess.run([sys.executable, "-m", "pip", "uninstall", "-y",
                "fastcore","fastdownload","fastprogress"], check=False)

# sanity check for remaining conflicts
subprocess.run([sys.executable, "-m", "pip", "check"])
# Out:
# Found existing installation: fastai 2.7.11
# Uninstalling fastai-2.7.11:
#   Successfully uninstalled fastai-2.7.11
# Found existing installation: fastcore 1.5.55
# Uninstalling fastcore-1.5.55:
#   Successfully uninstalled fastcore-1.5.55
# Found existing installation: fastdownload 0.0.7
# Uninstalling fastdownload-0.0.7:
#   Successfully uninstalled fastdownload-0.0.7
# Found existing installation: fastprogress 1.0.3
# Uninstalling fastprogress-1.0.3:
#   Successfully uninstalled fastprogress-1.0.3
# blis 1.0.1 has requirement numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4.
# thinc 8.3.2 has requirement numpy<2.1.0,>=2.0.0; python_version >= "3.9", but you have numpy 1.26.4.
# PyNaCl 1.5.0 is not supported on this platform
# CompletedProcess(args=['/usr/bin/python3', '-m', 'pip', 'check'], returncode=1)

# %%
import sys, subprocess, importlib.metadata as im

def installed(prefix):
    out = []
    for d in im.distributions():
        try:
            name = d.metadata['Name']
        except Exception:
            continue
        if name and name.lower().startswith(prefix):
            out.append(name)
    return sorted(set(out))

pkgs = []
pkgs += ['torch','torchvision','torchaudio','torchtext','torchdata','triton']
pkgs += installed('nvidia-')  # all nvidia-* wheels currently in this env

print("Uninstalling:", pkgs)
if pkgs:
    subprocess.run([sys.executable, "-m", "pip", "uninstall", "-y", *pkgs], check=False)
# Out:
# Uninstalling: ['torch', 'torchvision', 'torchaudio', 'torchtext', 'torchdata', 'triton', 'nvidia-cublas-cu11', 'nvidia-cublas-cu12', 'nvidia-cuda-cupti-cu11', 'nvidia-cuda-cupti-cu12', 'nvidia-cuda-nvrtc-cu11', 'nvidia-cuda-nvrtc-cu12', 'nvidia-cuda-runtime-cu11', 'nvidia-cuda-runtime-cu12', 'nvidia-cudnn-cu11', 'nvidia-cudnn-cu12', 'nvidia-cufft-cu11', 'nvidia-cufft-cu12', 'nvidia-cufile-cu12', 'nvidia-curand-cu11', 'nvidia-curand-cu12', 'nvidia-cusolver-cu11', 'nvidia-cusolver-cu12', 'nvidia-cusparse-cu11', 'nvidia-cusparse-cu12', 'nvidia-cusparselt-cu12', 'nvidia-nccl-cu11', 'nvidia-nccl-cu12', 'nvidia-nvjitlink-cu12', 'nvidia-nvshmem-cu12', 'nvidia-nvtx-cu11', 'nvidia-nvtx-cu12']
# Found existing installation: torch 2.4.1+cu121
# Uninstalling torch-2.4.1+cu121:
#   Successfully uninstalled torch-2.4.1+cu121
# Found existing installation: torchvision 0.14.1
# Uninstalling torchvision-0.14.1:
#   Successfully uninstalled torchvision-0.14.1
# Found existing installation: torchaudio 0.13.1
# Uninstalling torchaudio-0.13.1:
#   Successfully uninstalled torchaudio-0.13.1
# Found existing installation: torchtext 0.14.1
# Uninstalling torchtext-0.14.1:
#   Successfully uninstalled torchtext-0.14.1
# Found existing installation: torchdata 0.5.1
# Uninstalling torchdata-0.5.1:
#   Successfully uninstalled torchdata-0.5.1
# Found existing installation: triton 3.0.0
# Uninstalling triton-3.0.0:
#   Successfully uninstalled triton-3.0.0
# Found existing installation: nvidia-cublas-cu11 11.10.3.66
# Uninstalling nvidia-cublas-cu11-11.10.3.66:
#   Successfully uninstalled nvidia-cublas-cu11-11.10.3.66
# Found existing installation: nvidia-cublas-cu12 12.1.3.1
# Uninstalling nvidia-cublas-cu12-12.1.3.1:
#   Successfully uninstalled nvidia-cublas-cu12-12.1.3.1
# Found existing installation: nvidia-cuda-cupti-cu11 11.8.87
# Uninstalling nvidia-cuda-cupti-cu11-11.8.87:
#   Successfully uninstalled nvidia-cuda-cupti-cu11-11.8.87
# Found existing installation: nvidia-cuda-cupti-cu12 12.1.105
# Uninstalling nvidia-cuda-cupti-cu12-12.1.105:
#   Successfully uninstalled nvidia-cuda-cupti-cu12-12.1.105
# Found existing installation: nvidia-cuda-nvrtc-cu11 11.7.99
# Uninstalling nvidia-cuda-nvrtc-cu11-11.7.99:
#   Successfully uninstalled nvidia-cuda-nvrtc-cu11-11.7.99
# Found existing installation: nvidia-cuda-nvrtc-cu12 12.1.105
# Uninstalling nvidia-cuda-nvrtc-cu12-12.1.105:
#   Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.1.105
# Found existing installation: nvidia-cuda-runtime-cu11 11.7.99
# Uninstalling nvidia-cuda-runtime-cu11-11.7.99:
#   Successfully uninstalled nvidia-cuda-runtime-cu11-11.7.99
# Found existing installation: nvidia-cuda-runtime-cu12 12.1.105
# Uninstalling nvidia-cuda-runtime-cu12-12.1.105:
#   Successfully uninstalled nvidia-cuda-runtime-cu12-12.1.105
# Found existing installation: nvidia-cudnn-cu11 8.5.0.96
# Uninstalling nvidia-cudnn-cu11-8.5.0.96:
#   Successfully uninstalled nvidia-cudnn-cu11-8.5.0.96
# Found existing installation: nvidia-cudnn-cu12 9.1.0.70
# Uninstalling nvidia-cudnn-cu12-9.1.0.70:
#   Successfully uninstalled nvidia-cudnn-cu12-9.1.0.70
# Found existing installation: nvidia-cufft-cu11 10.9.0.58
# Uninstalling nvidia-cufft-cu11-10.9.0.58:
#   Successfully uninstalled nvidia-cufft-cu11-10.9.0.58
# Found existing installation: nvidia-cufft-cu12 11.0.2.54
# Uninstalling nvidia-cufft-cu12-11.0.2.54:
#   Successfully uninstalled nvidia-cufft-cu12-11.0.2.54
# Found existing installation: nvidia-cufile-cu12 1.13.1.3
# Uninstalling nvidia-cufile-cu12-1.13.1.3:
#   Successfully uninstalled nvidia-cufile-cu12-1.13.1.3
# Found existing installation: nvidia-curand-cu11 10.3.0.86
# Uninstalling nvidia-curand-cu11-10.3.0.86:
#   Successfully uninstalled nvidia-curand-cu11-10.3.0.86
# Found existing installation: nvidia-curand-cu12 10.3.2.106
# Uninstalling nvidia-curand-cu12-10.3.2.106:
#   Successfully uninstalled nvidia-curand-cu12-10.3.2.106
# Found existing installation: nvidia-cusolver-cu11 11.4.1.48
# Uninstalling nvidia-cusolver-cu11-11.4.1.48:
#   Successfully uninstalled nvidia-cusolver-cu11-11.4.1.48
# Found existing installation: nvidia-cusolver-cu12 11.4.5.107
# Uninstalling nvidia-cusolver-cu12-11.4.5.107:
#   Successfully uninstalled nvidia-cusolver-cu12-11.4.5.107
# Found existing installation: nvidia-cusparse-cu11 11.7.5.86
# Uninstalling nvidia-cusparse-cu11-11.7.5.86:
#   Successfully uninstalled nvidia-cusparse-cu11-11.7.5.86
# Found existing installation: nvidia-cusparse-cu12 12.1.0.106
# Uninstalling nvidia-cusparse-cu12-12.1.0.106:
#   Successfully uninstalled nvidia-cusparse-cu12-12.1.0.106
# Found existing installation: nvidia-cusparselt-cu12 0.7.1
# Uninstalling nvidia-cusparselt-cu12-0.7.1:
#   Successfully uninstalled nvidia-cusparselt-cu12-0.7.1
# Found existing installation: nvidia-nccl-cu11 2.20.5
# Uninstalling nvidia-nccl-cu11-2.20.5:
#   Successfully uninstalled nvidia-nccl-cu11-2.20.5
# Found existing installation: nvidia-nccl-cu12 2.20.5
# Uninstalling nvidia-nccl-cu12-2.20.5:
#   Successfully uninstalled nvidia-nccl-cu12-2.20.5
# Found existing installation: nvidia-nvjitlink-cu12 12.8.93
# Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#   Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
# Found existing installation: nvidia-nvshmem-cu12 3.3.20
# Uninstalling nvidia-nvshmem-cu12-3.3.20:
#   Successfully uninstalled nvidia-nvshmem-cu12-3.3.20
# Found existing installation: nvidia-nvtx-cu11 11.8.86
# Uninstalling nvidia-nvtx-cu11-11.8.86:
#   Successfully uninstalled nvidia-nvtx-cu11-11.8.86
# Found existing installation: nvidia-nvtx-cu12 12.1.105
# Uninstalling nvidia-nvtx-cu12-12.1.105:
#   Successfully uninstalled nvidia-nvtx-cu12-12.1.105

# %%
import sys, subprocess
subprocess.run([sys.executable, "-m", "pip", "install", "-U", "pip"], check=True)

# Torch will pull matching CUDA wheels automatically, including cuDNN (libcudnn.so.9)
subprocess.run([sys.executable, "-m", "pip", "install",
                "--index-url", "https://download.pytorch.org/whl/cu121",
                "torch==2.4.1"], check=True)

# Optional extras (only if you need them); otherwise skip to avoid version churn
# subprocess.run([sys.executable, "-m", "pip", "install",
#                 "--index-url", "https://download.pytorch.org/whl/cu121",
#                 "torchvision==0.19.1", "torchaudio==2.4.1"], check=True)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (25.3)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Collecting torch==2.4.1
#   Downloading https://download.pytorch.org/whl/cu121/torch-2.4.1%2Bcu121-cp310-cp310-linux_x86_64.whl (798.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.9/798.9 MB 6.3 MB/s  0:01:56 eta 0:00:010:00:04
# Requirement already satisfied: filelock in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (4.12.2)
# Requirement already satisfied: sympy in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (1.14.0)
# Requirement already satisfied: networkx in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (3.4.2)
# Requirement already satisfied: jinja2 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (3.1.4)
# Requirement already satisfied: fsspec in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (2024.9.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.4.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 9.1 MB/s  0:00:02m 9.5 MB/s eta 0:00:01
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.4.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 5.9 MB/s  0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.4.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 7.7 MB/s  0:00:018.0 MB/s eta 0:00:01:01
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.4.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 6.4 MB/s  0:01:30 eta 0:00:010:00:03
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.4.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 6.7 MB/s  0:01:04 eta 0:00:010:00:02
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.4.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 6.8 MB/s  0:00:17 eta 0:00:010:01:02
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.4.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 5.2 MB/s  0:00:10 eta 0:00:010:00:01
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.4.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.7 MB/s  0:00:16 eta 0:00:010:00:01
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.4.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 7.5 MB/s  0:00:25 eta 0:00:010:00:01
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.4.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 8.2 MB/s  0:00:21 eta 0:00:010:00:01
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.4.1)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Collecting triton==3.0.0 (from torch==2.4.1)
#   Downloading https://download.pytorch.org/whl/triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 2.2 MB/s  0:01:45 eta 0:00:010:00:04
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.4.1)
#   Downloading https://download.pytorch.org/whl/nvidia_nvjitlink_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->torch==2.4.1) (2.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from sympy->torch==2.4.1) (1.3.0)
# Downloading https://download.pytorch.org/whl/nvidia_nvjitlink_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.7/39.7 MB 4.9 MB/s  0:00:08 eta 0:00:010:00:01
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━ 13/14 [torch]-cusolver-cu12]e-cu12]2]
# ERROR: Could not install packages due to an OSError: [Errno 28] No space left on device
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[7], line 5
#       2 subprocess.run([sys.executable, "-m", "pip", "install", "-U", "pip"], check=True)
#       4 # Torch will pull matching CUDA wheels automatically, including cuDNN (libcudnn.so.9)
# ----> 5 subprocess.run([sys.executable, "-m", "pip", "install",
#       6                 "--index-url", "https://download.pytorch.org/whl/cu121",
#       7                 "torch==2.4.1"], check=True)
#       9 # Optional extras (only if you need them); otherwise skip to avoid version churn
#      10 # subprocess.run([sys.executable, "-m", "pip", "install",
#      11 #                 "--index-url", "https://download.pytorch.org/whl/cu121",
#      12 #                 "torchvision==0.19.1", "torchaudio==2.4.1"], check=True)
#
# File /usr/lib/python3.10/subprocess.py:526, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     524     retcode = process.poll()
#     525     if check and retcode:
# --> 526         raise CalledProcessError(retcode, process.args,
#     527                                  output=stdout, stderr=stderr)
#     528 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['/usr/bin/python3', '-m', 'pip', 'install', '--index-url', 'https://download.pytorch.org/whl/cu121', 'torch==2.4.1']' returned non-zero exit status 1.

# %%
import sys, site, pkgutil, subprocess, pathlib, os
print("PY:", sys.executable)
print("site-packages:", [p for p in sys.path if p.endswith("site-packages")])
print("LD_LIBRARY_PATH(before):", os.environ.get("LD_LIBRARY_PATH",""))

# What torch & cudnn does this kernel see?
subprocess.run([sys.executable, "-m", "pip", "show", "torch", "nvidia-cudnn-cu12"])
try:
    import nvidia.cudnn as nc
    libdir = pathlib.Path(nc.__file__).parent / "lib"
    print("cudnn python pkg:", nc.__file__)
    print("cudnn lib dir exists:", libdir, libdir.exists())
    if libdir.exists():
        print("cudnn libs:", [p.name for p in libdir.glob("libcudnn*.so*")])
except Exception as e:
    print("import nvidia.cudnn failed:", e)
# Out:
# PY: /usr/bin/python3
# site-packages: ['/home/mallarapuhemavarshini/.local/lib/python3.10/site-packages']
# LD_LIBRARY_PATH(before):
# Name: torch
# Version: 2.4.1+cu121
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages
# Requires: filelock, fsspec, jinja2, networkx, nvidia-cublas-cu12, nvidia-cuda-cupti-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-runtime-cu12, nvidia-cudnn-cu12, nvidia-cufft-cu12, nvidia-curand-cu12, nvidia-cusolver-cu12, nvidia-cusparse-cu12, nvidia-nccl-cu12, nvidia-nvtx-cu12, sympy, triton, typing-extensions
# Required-by: fastai, ogb, sentence-transformers, torchaudio, torchdata, torchtext, torchvision
# ---
# Name: nvidia-cudnn-cu12
# Version: 9.1.0.70
# Summary: cuDNN runtime libraries
# Home-page: https://developer.nvidia.com/cuda-zone
# Author: Nvidia CUDA Installer Team
# Author-email: cuda_installer@nvidia.com
# License: NVIDIA Proprietary Software
# Location: /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages
# Requires: nvidia-cublas-cu12
# Required-by: torch
# cudnn python pkg: /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages/nvidia/cudnn/__init__.py
# cudnn lib dir exists: /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages/nvidia/cudnn/lib True
# cudnn libs: ['libcudnn_ops_infer.so.8', 'libcudnn_ops_train.so.8', 'libcudnn_cnn_train.so.8', 'libcudnn_adv_train.so.8', 'libcudnn.so.8', 'libcudnn_cnn_infer.so.8', 'libcudnn_adv_infer.so.8']

# %%
# Optional: install
#!pip install -r requirements.txt


# !pip install --index-url https://download.pytorch.org/whl/cu121 torch==2.4.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: torch==2.4.1 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (2.4.1+cu121)
# Requirement already satisfied: sympy in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (1.14.0)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (10.3.2.106)
# Requirement already satisfied: fsspec in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (2024.9.0)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (9.1.0.70)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (11.4.5.107)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (2.20.5)
# Requirement already satisfied: triton==3.0.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (3.0.0)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (12.1.0.106)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (4.12.2)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (12.1.3.1)
# Requirement already satisfied: filelock in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (3.16.1)
# Requirement already satisfied: networkx in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (3.4.2)
# Requirement already satisfied: jinja2 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (3.1.4)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (12.1.105)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (11.0.2.54)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch==2.4.1) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.4.1) (12.8.93)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->torch==2.4.1) (2.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from sympy->torch==2.4.1) (1.3.0)

# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ir_datasets==0.5.6 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (0.5.6)
# Requirement already satisfied: rank_bm25==0.2.2 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: sentence-transformers==3.0.1 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (3.0.1)
# Requirement already satisfied: faiss-cpu==1.8.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: scikit-learn==1.4.2 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied: tqdm==4.66.4 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (4.66.4)
# Requirement already satisfied: numpy==1.26.4 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: matplotlib>=3.8.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (3.9.2)
# Requirement already satisfied: transformers>=4.41.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (4.57.1)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (4.12.3)
# Requirement already satisfied: inscriptis>=2.2.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (2.6.0)
# Requirement already satisfied: lxml>=4.5.2 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/lib/python3/dist-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (5.4.1)
# Requirement already satisfied: requests>=2.22.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (2.6)
# Requirement already satisfied: lz4>=3.1.10 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (4.4.5)
# Requirement already satisfied: warc3-wet>=0.2.3 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (0.1.10)
# Requirement already satisfied: ijson>=3.1.3 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (3.4.0.post0)
# Requirement already satisfied: pyautocorpus>=0.1.1 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (0.1.12)
# Requirement already satisfied: unlzw3>=0.2.1 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from ir_datasets==0.5.6->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: torch>=1.11.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from sentence-transformers==3.0.1->-r requirements.txt (line 3)) (2.4.1+cu121)
# Requirement already satisfied: scipy in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from sentence-transformers==3.0.1->-r requirements.txt (line 3)) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from sentence-transformers==3.0.1->-r requirements.txt (line 3)) (0.36.0)
# Requirement already satisfied: Pillow in /usr/lib/python3/dist-packages (from sentence-transformers==3.0.1->-r requirements.txt (line 3)) (9.0.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from scikit-learn==1.4.2->-r requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from scikit-learn==1.4.2->-r requirements.txt (line 5)) (3.5.0)
# Requirement already satisfied: filelock in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from transformers>=4.41.0->-r requirements.txt (line 9)) (3.16.1)
# Requirement already satisfied: packaging>=20.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from transformers>=4.41.0->-r requirements.txt (line 9)) (24.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from transformers>=4.41.0->-r requirements.txt (line 9)) (2025.10.23)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from transformers>=4.41.0->-r requirements.txt (line 9)) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from transformers>=4.41.0->-r requirements.txt (line 9)) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from matplotlib>=3.8.0->-r requirements.txt (line 8)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from matplotlib>=3.8.0->-r requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from matplotlib>=3.8.0->-r requirements.txt (line 8)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from matplotlib>=3.8.0->-r requirements.txt (line 8)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.8.0->-r requirements.txt (line 8)) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from matplotlib>=3.8.0->-r requirements.txt (line 8)) (2.9.0.post0)
# Requirement already satisfied: soupsieve>1.2 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from beautifulsoup4>=4.4.1->ir_datasets==0.5.6->-r requirements.txt (line 1)) (2.6)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.8.0->-r requirements.txt (line 8)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from requests>=2.22.0->ir_datasets==0.5.6->-r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.22.0->ir_datasets==0.5.6->-r requirements.txt (line 1)) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.22.0->ir_datasets==0.5.6->-r requirements.txt (line 1)) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.22.0->ir_datasets==0.5.6->-r requirements.txt (line 1)) (2020.6.20)
# Requirement already satisfied: sympy in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (1.14.0)
# Requirement already satisfied: networkx in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (3.4.2)
# Requirement already satisfied: jinja2 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (12.9.86)
# Requirement already satisfied: cbor>=1.0.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from trec-car-tools>=2.5.4->ir_datasets==0.5.6->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mallarapuhemavarshini/.local/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence-transformers==3.0.1->-r requirements.txt (line 3)) (1.3.0)

# %%
# shell cell
# !python3 -m ir_datasets list | grep trec-covid
# Out:
# beir/trec-covid
# cord19/fulltext/trec-covid
# cord19/trec-covid
# cord19/trec-covid/round1
# cord19/trec-covid/round2
# cord19/trec-covid/round3
# cord19/trec-covid/round4
# cord19/trec-covid/round5

# %%
from __future__ import annotations
import os, re, json
from pathlib import Path
from typing import Iterable, Dict
import ir_datasets
from tqdm import tqdm

WORK_DIR = Path("./work")
#DATASET = "beir/trec-covid/test"   # ← dev → test
DATASET = "beir/trec-covid"
#ds = ir_datasets.load(DATASET)

WORK_DIR.mkdir(parents=True, exist_ok=True)

try:
    ds = ir_datasets.load(DATASET)
except KeyError:
    raise SystemExit(
        f"Dataset key '{DATASET}' not found. "
        "Try installing BEIR extras: pip install -U 'ir_datasets[beir]' "
        "or list available names with: python -m ir_datasets list"
    )

ds_dir = WORK_DIR / "datasets" / DATASET.replace("/", "_")
ds_dir.mkdir(parents=True, exist_ok=True)

# %%
from __future__ import annotations
import os, re, json
from pathlib import Path
from typing import Iterable, Dict
import ir_datasets
from tqdm import tqdm

WORK_DIR = Path("./work")               # change if needed
DATASET = "beir/trec-covid"
# e.g., 'msmarco-passage/train', 'beir/nfcorpus/test'
#DATASET = "msmarco-passage/train"
WORK_DIR.mkdir(parents=True, exist_ok=True)
ds = ir_datasets.load(DATASET)
ds_dir = WORK_DIR / "datasets" / DATASET.replace("/", "_")
ds_dir.mkdir(parents=True, exist_ok=True)

def clean_text(text: str) -> str:
    if text is None: return ""
    text = text.lower()
    text = re.sub(r"\s+", " ", text)
    text = re.sub(r"[^a-z0-9\s\-\.,;:!?/()'\"]+", " ", text)
    return text.strip()

def tokenize_simple(text: str):
    import re
    return re.findall(r"[a-z0-9]+", text.lower())

def save_jsonl(path: Path, rows: Iterable[dict]):
    path.parent.mkdir(parents=True, exist_ok=True)
    with path.open("w", encoding="utf-8") as f:
        for r in rows:
            f.write(json.dumps(r, ensure_ascii=False) + "\n")

# %%
import torch

print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
else:
    print("No GPU detected — running on CPU.")
# Out:
# PyTorch version: 2.4.1+cu121
# CUDA available: True
# GPU name: NVIDIA GeForce RTX 3050 Laptop GPU

# %%
import os
queries_out = ds_dir / "queries.jsonl"
if queries_out.exists():
    os.remove(queries_out)
    print("Deleted old queries.jsonl")

# Now re-run the export cell below

# %%
# Export corpus (clean + truncate for transformer inputs)
MAX_TOK = 512
MAX_DOCS = 10000   # ← small test limit; BEIR/TREC-COVID has only ~170k docs anyway

corpus_out = ds_dir / "corpus.jsonl"

# Always overwrite for a fresh start (recommended)
with corpus_out.open("w", encoding="utf-8") as f:
    for i, d in enumerate(tqdm(ds.docs_iter(), desc=f"Export corpus (up to {MAX_DOCS})")):
        if i >= MAX_DOCS:
            break
        txt = ""
        if hasattr(d, "text") and d.text:
            txt = d.text
        if hasattr(d, "title") and d.title:
            txt = (d.title + " " + txt).strip()
        txt = clean_text(txt)
        toks = tokenize_simple(txt)[:MAX_TOK]
        txt = " ".join(toks)
        f.write(json.dumps(
            {"doc_id": str(d.doc_id), "text": txt, "len": len(toks)},
            ensure_ascii=False
        ) + "\n")

print(f"✅ Exported {min(i + 1, MAX_DOCS)} documents to {corpus_out}")
# Out:
# Export corpus (up to 10000): 10000it [00:00, 11092.96it/s]
# ✅ Exported 10000 documents to work/datasets/beir_trec-covid/corpus.jsonl

# %%
# Export queries
queries_out = ds_dir / "queries.jsonl"
if not queries_out.exists():
    with queries_out.open("w", encoding="utf-8") as f:
        for q in tqdm(ds.queries_iter(), desc="Export queries"):
            txt = clean_text(getattr(q, "text", ""))
            f.write(json.dumps({"qid": str(q.query_id), "text": txt}, ensure_ascii=False) + "\n")
else:
    print("queries.jsonl already exists")
# Out:
# Export queries: 50it [00:00, 47771.12it/s]

# %%
# Export qrels
qrels_out = ds_dir / "qrels.jsonl"
if not qrels_out.exists():
    with qrels_out.open("w", encoding="utf-8") as f:
        for r in tqdm(ds.qrels_iter(), desc="Export qrels"):
            f.write(json.dumps({"qid": str(r.query_id), "doc_id": str(r.doc_id), "rel": int(r.relevance)}) + "\n")
else:
    print("qrels.jsonl already exists")
# Out:
# Export qrels: 66336it [00:00, 267907.65it/s]

# %% [markdown]
# ✅ **Done.** You can now generate stratified subsets from these JSONL files in Notebook 2.
